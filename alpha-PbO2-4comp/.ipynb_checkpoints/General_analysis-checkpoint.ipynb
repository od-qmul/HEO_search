# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kB = 8.6173303E-5 #eV/K

# %%
file = "./summary_alphaPbO2_deltaHvsigma_ordered_Ei.csv"
df_alpha = pd.read_csv(file)
df_alpha
# Out:
#                       Formula       Energy  sigma bond length  Bond length  \
# 0    ['Sn', 'Zr', 'Pb', 'Nb'] -5870.681236           0.143319     2.148477
# 1     ['Sn', 'Pb', 'Nb', 'V'] -5535.784593           0.151722     2.111285
# 2    ['Hf', 'Zr', 'Pb', 'Nb'] -6619.323403           0.126937     2.121745
# 3    ['Ti', 'Hf', 'Pb', 'Nb'] -6516.814641           0.176848     2.108503
# 4    ['Ti', 'Zr', 'Pb', 'Nb'] -6382.341198           0.179601     2.116673
# ..                        ...          ...                ...          ...
# 813  ['Sn', 'Ce', 'Rh', 'Mn'] -5392.924049           0.114534     2.084567
# 814  ['Ti', 'Ce', 'Rh', 'Mn'] -5911.874665           0.134058     2.055369
# 815  ['Hf', 'Ce', 'Rh', 'Mn'] -6140.779541           0.117968     2.083824
# 816  ['Ge', 'Pb', 'Ce', 'Mn'] -5208.660148           0.176434     2.115153
# 817  ['Ge', 'Ce', 'Ir', 'Mn'] -5531.697528           0.138962     2.048466
#
#       O sigma  Cation sigma    DeltaH           T/K
# ...

# %%
def plot_columns(df, col_x, col_y, filter_col, filter_list,fname):
    """
    Plots col_x against col_y for rows where any of the strings in filter_list appear in filter_col.

    Parameters:
    - df: pandas DataFrame
    - col_x: str, column name to be plotted on the x-axis
    - col_y: str, column name to be plotted on the y-axis
    - filter_col: str, column name to apply the filter
    - filter_list: list of strings to filter filter_col

    Returns:
    - A scatter plot of col_x vs col_y for the filtered rows.
    """
    # Filter rows where filter_col contains any of the strings in filter_list
    filtered_df = df[~df[filter_col].astype(str).str.contains('|'.join(filter_list), na=False)]
    
    # Plot col_x against col_y
    plt.figure(figsize=(8, 6))
    plt.scatter(filtered_df[col_x], filtered_df[col_y], color='b', alpha=0.7, label=('Exclude '+','.join(filter_list)))
    plt.xlabel(col_x)
    plt.ylabel(col_y)
    plt.title(f"Plot of {col_x} vs {col_y} for Filtered Rows")
    plt.legend()
    plt.grid(True)
    plt.savefig(fname)
    plt.show()

# %%
excl_list = ['Nb','Mn']

# %%
plot_columns(df=df_alpha, col_x='Cation sigma', col_y= 'sigma bond length', filter_col='Formula', filter_list=excl_list,fname="scatter_Ei_v_bond_aPbO2.png")

# %%
filtered_df = df_alpha[~df_alpha['Formula'].astype(str).str.contains('|'.join(excl_list), na=False)]
csvfilestr = "./summary_alphaPbO2_ordered.csv"
filtered_df.to_csv(csvfilestr, index=False)
filtered_df
# Out:
#                       Formula       Energy  sigma bond length  Bond length  \
# 111   ['Sn', 'Zr', 'Pb', 'V'] -5532.147285           0.124084     2.104366
# 115   ['Sn', 'Hf', 'Pb', 'V'] -5660.293488           0.116782     2.094234
# 118   ['Sn', 'Pb', 'Pt', 'V'] -4812.921649           0.114624     2.082989
# 119   ['Hf', 'Zr', 'Pb', 'V'] -6277.840073           0.131842     2.103700
# 122   ['Ti', 'Sn', 'Pb', 'V'] -5425.557770           0.132520     2.069825
# ..                        ...          ...                ...          ...
# 602  ['Ge', 'Sn', 'Ce', 'Ru'] -5413.147249           0.135658     2.077921
# 603  ['Ge', 'Ti', 'Ce', 'Ir'] -5861.007946           0.141190     2.049852
# 604  ['Ge', 'Sn', 'Ce', 'Ir'] -5341.246201           0.123684     2.079549
# 605  ['Ge', 'Ce', 'Ru', 'Ir'] -5549.804449           0.153915     2.069881
# 606  ['Ti', 'Hf', 'Ru', 'Ir'] -6277.727609           0.083821     2.080138
#
#       O sigma  Cation sigma    DeltaH          T/K
# ...

# %%
ncat=4

def H_to_T(eV):
    return (eV/(kB * np.log(ncat)))

def T_to_H(K):
    return (K * (kB * np.log(ncat)))

fig, ax = plt.subplots(figsize=(8, 8))

# Customizing the plot
ax.set_xlabel('Bond $\sigma$ ($\AA$)')
ax.set_ylabel('E$_i$ $\sigma$ (eV)')

ax.scatter(filtered_df['sigma bond length'], filtered_df['Cation sigma'], color='blue', s=100, alpha=0.7)

# ax.fill_betweenx([0.0, 0.1], 0.0, T_to_H(1800), color='green', alpha=0.3)

ax.legend()
ax.grid(True)

ax.set_xlim(0.0,0.20)
ax.set_ylim(0.0,0.12)

# # Top x-axis: temperature in K
# secax = ax.secondary_xaxis('top', functions=(H_to_T, T_to_H))
# secax.set_xlabel("Temperature (K)")

plt.rcParams.update({'font.size': 14})  # Set default font size

plt.savefig('./scatter_bond_v_Ei_aPbO2.png')

plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1013/1770956869.py:12: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_xlabel('Bond $\sigma$ ($\AA$)')
# /tmp/ipykernel_1013/1770956869.py:13: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_ylabel('E$_i$ $\sigma$ (eV)')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
search_string = "Nb"
catcontain = df_alpha[df_alpha['Formula'].astype(str).str.contains(search_string, na=False)]
notcontain = df_alpha[df_alpha['Formula'].astype(str).str.contains(search_string, na=True)]

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Customizing the plot
ax.set_xlabel('$\Delta$H (eV/formula unit)')
ax.set_ylabel('$E_{i}$ $\sigma$ (eV)')

ax.scatter(catcontain['DeltaH'], catcontain['Cation sigma'], color='blue', label='Pb', s=100, alpha=0.7)

#ax.scatter(notcontain['DeltaH'], notcontain['Cation sigma'], color='orange', label='Others', s=100, alpha=0.7)

ax.set_title("4-component alpha-PbO2 A$O$_2$")

ax.fill_betweenx([0.0, 0.1], 0.0, 0.4, color='green', alpha=0.3)

ax.legend()
ax.grid(True)

#plt.savefig('./SUMMARY_cor_bixby/deltaH_v_Eisigma_corbix_5comp.png')

plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_9170/1771996350.py:4: SyntaxWarning: invalid escape sequence '\D'
#   ax.set_xlabel('$\Delta$H (eV/formula unit)')
# /tmp/ipykernel_9170/1771996350.py:5: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_ylabel('$E_{i}$ $\sigma$ (eV)')
