# %%
import os
import glob
import pandas as pd
import numpy as np
import ast

# %%
file1 = "./summary_alphaPbO2_deltaHvsigma_ordered_Ei_minbin.csv"
df_aPbO2_comp = pd.read_csv(file1)

file2 = "./summary_4comp_bad_Ei_order_binmin.csv"
df_bad_comp = pd.read_csv(file2)

file3 = "./summary_4comp_rutile_Ei_order_binmin.csv"
df_rut_comp = pd.read_csv(file3)

# %%
df1 = df_aPbO2_comp
df2 = df_bad_comp
df4 = df_rut_comp

# Function to preprocess each DataFrame by appending titles to column names
def preprocess_df_with_titles(df, title):
    df = df[['Formula', 'sigma bond length', 'Cation sigma', 'DeltaH']]
    df.columns = ['Formula'] + [f"{col}_{title}" for col in df.columns[1:]]
    return df

def normalize_formula(formula):
    # Convert string representation to a Python list
    elements = ast.literal_eval(formula)
    # Sort elements and convert back to string
    return str(sorted(elements))

# Normalize the formulas in both DataFrames
df1['Formula'] = df1['Formula'].apply(normalize_formula)
df2['Formula'] = df2['Formula'].apply(normalize_formula)
df4['Formula'] = df4['Formula'].apply(normalize_formula)

titles = ['aPbO2', 'bad', 'fluor', 'rut']
# Preprocess each DataFrame with respective titles
df1 = preprocess_df_with_titles(df1, titles[0])
df2 = preprocess_df_with_titles(df2, titles[1])
df4 = preprocess_df_with_titles(df4, titles[3])

# Merge all DataFrames on 'Formula' with an outer join
merged_df = df1.merge(df2, on='Formula', how='outer') \
               .merge(df4, on='Formula', how='outer')

# Display the final merged DataFrame
merged_df.head()
# Out:
#                     Formula  sigma bond length_aPbO2  Cation sigma_aPbO2  \
# 0  ['Ce', 'Ge', 'Hf', 'Ir']                 0.127892            0.072767
# 1  ['Ce', 'Ge', 'Hf', 'Mn']                 0.146676            0.084239
# 2  ['Ce', 'Ge', 'Hf', 'Nb']                 0.163084            0.094952
# 3  ['Ce', 'Ge', 'Hf', 'Pb']                 0.143940            0.069778
# 4  ['Ce', 'Ge', 'Hf', 'Pt']                 0.128346            0.074133
#
#    DeltaH_aPbO2  sigma bond length_bad  Cation sigma_bad  DeltaH_bad  \
# 0      0.461590               0.130436          0.075256    0.466841
# 1      0.325290               0.141323          0.084368    0.323455
# 2      0.518559                    NaN               NaN         NaN
# 3      0.291689               0.146666          0.072580    0.297499
# 4      0.354258               0.125677          0.081444    0.354506
#
#    sigma bond length_rut  Cation sigma_rut  DeltaH_rut
# 0               0.120833          0.088627    0.457033
# 1               0.130369          0.092075    0.354483
# 2               0.152112          0.107321    0.578145
# 3               0.133715          0.085034    0.342001
# 4               0.116889          0.084023    0.360637

# %%
titles = ['aPbO2','bad','rut']
wsigma = 0.0299359345584294*np.sqrt(2)
wH = 0.0750966429584929*np.sqrt(2)

for crys in titles:
    colname = "rho_"+crys
    merged_df[colname] = merged_df.apply(lambda row: np.sqrt( (row["Cation sigma_"+crys]/wsigma)**2 + (row["DeltaH_"+crys]/wH)**2),axis=1)

# %%
deltaH_cols = [col for col in merged_df.columns if col.startswith("rho_")]
merged_df['Min_rho'] = merged_df[deltaH_cols].min(axis=1)
merged_df['Min_Crystal_rho'] = merged_df[deltaH_cols].idxmin(axis=1).str.split('_').str[-1]
merged_df = merged_df.sort_values(by='Min_rho')

# %%
merged_df.head(20)
# Out:
#                       Formula  sigma bond length_aPbO2  Cation sigma_aPbO2  \
# 628  ['Hf', 'Pb', 'Sn', 'Zr']                 0.065397            0.032896
# 664  ['Hf', 'Sn', 'Ti', 'Zr']                 0.094455            0.029936
# 751  ['Ir', 'Pt', 'Rh', 'Ru']                      NaN                 NaN
# 626  ['Hf', 'Pb', 'Sn', 'Ti']                 0.098810            0.035875
# 613  ['Hf', 'Pb', 'Pt', 'Sn']                      NaN                 NaN
# 641  ['Hf', 'Pt', 'Sn', 'Ti']                 0.066732            0.043735
# 958  ['Pb', 'Sn', 'Ti', 'Zr']                 0.102560            0.037092
# 630  ['Hf', 'Pb', 'Ti', 'Zr']                 0.109435            0.036594
# 415   ['Ge', 'Mn', 'Ti', 'V']                      NaN                 NaN
# 331  ['Ge', 'Hf', 'Sn', 'Ti']                 0.096572            0.038340
# 768   ['Ir', 'Rh', 'Ru', 'V']                      NaN                 NaN
# 753  ['Ir', 'Pt', 'Rh', 'Ti']                 0.034325            0.043172
# 634  ['Hf', 'Pt', 'Rh', 'Ti']                 0.054520            0.044304
# 935  ['Pb', 'Pt', 'Sn', 'Ti']                 0.098021            0.045704
# 333  ['Ge', 'Hf', 'Sn', 'Zr']                 0.092623            0.039898
# 410   ['Ge', 'Mn', 'Ru', 'V']                 0.065625            0.061179
# 754   ['Ir', 'Pt', 'Rh', 'V']                      NaN                 NaN
# 643  ['Hf', 'Pt', 'Sn', 'Zr']                 0.052179            0.044848
# 645  ['Hf', 'Pt', 'Ti', 'Zr']                 0.080473            0.044615
# 403  ['Ge', 'Mn', 'Rh', 'Ru']                 0.042410            0.054822
#
#      DeltaH_aPbO2  sigma bond length_bad  Cation sigma_bad  DeltaH_bad  \
# 628      0.057140               0.066538          0.036035    0.057542
# 664      0.075097                    NaN               NaN         NaN
# 751           NaN                    NaN               NaN         NaN
# 626      0.101784               0.100108          0.035562    0.103064
# 613           NaN               0.070457          0.049715    0.113711
# 641      0.118722               0.066938          0.046483    0.109328
# 958      0.096296               0.105499          0.037213    0.090494
# 630      0.106772               0.106625          0.035773    0.108955
# 415           NaN               0.086187          0.060839    0.116704
# 331      0.127128               0.094645          0.039369    0.130397
# 768           NaN               0.042985          0.039595    0.130849
# 753      0.135085                    NaN               NaN         NaN
# 634      0.141013               0.053816          0.040623    0.143618
# 935      0.137010               0.098265          0.045480    0.139314
# 333      0.123522               0.092271          0.038700    0.137028
# 410      0.131495               0.061699          0.060000    0.126022
# 754           NaN                    NaN               NaN         NaN
# 643      0.118756               0.052469          0.044038    0.115654
# 645      0.129063               0.080232          0.045688    0.125407
# 403      0.135651               0.041302          0.056647    0.127724
#
#      sigma bond length_rut  Cation sigma_rut  DeltaH_rut  rho_aPbO2   rho_bad  \
# 628               0.041580          0.033870    0.047034   0.945108  1.008977
# 664               0.066255          0.032920    0.079332   1.000000       NaN
# 751               0.148573          0.039978    0.037992        NaN       NaN
# 626               0.077415          0.033567    0.078150   1.279286  1.283504
# 613               0.060433          0.038467    0.085627        NaN  1.589145
# 641               0.050232          0.042128    0.074849   1.522117  1.505077
# 958               0.085680          0.041022    0.085259   1.260865  1.224218
# 630               0.086395          0.033514    0.103019   1.325856  1.329093
# 415               0.047214          0.048684    0.054148        NaN  1.809051
# 331               0.070286          0.037126    0.100896   1.501008  1.540225
# 768               0.036835          0.044462    0.083010        NaN  1.546836
# 753               0.033025          0.046782    0.078845   1.630272       NaN
# 634               0.047619          0.046431    0.081203   1.690597  1.658145
# 935               0.082977          0.040050    0.101145   1.682187  1.695526
# 333               0.066689          0.034650    0.117442   1.496971  1.581259
# 410               0.044556          0.051259    0.069444   1.902974  1.848406
# 754               0.043880          0.048766    0.081166        NaN       NaN
# 643               0.030370          0.047998    0.084242   1.540327  1.505970
# 645               0.059314          0.044905    0.095258   1.608550  1.599678
# 403               0.033518          0.049350    0.080376   1.818869  1.799085
#
#       rho_rut   Min_rho Min_Crystal_rho
# 628  0.914431  0.914431             rut
# 664  1.078258  1.000000           aPbO2
# 751  1.009792  1.009792             rut
# 626  1.081725  1.081725             rut
# 613  1.214754  1.214754             rut
# 641  1.219387  1.219387             rut
# 958  1.258317  1.224218             bad
# 630  1.252039  1.252039             rut
# 415  1.257908  1.257908             rut
# 331  1.292900  1.292900             rut
# 768  1.309161  1.309161             rut
# 753  1.331247  1.331247             rut
# 634  1.336946  1.336946             rut
# 935  1.342372  1.342372             rut
# 333  1.375762  1.375762             rut
# 410  1.376061  1.376061             rut
# 754  1.382370  1.382370             rut
# 643  1.383674  1.383674             rut
# 645  1.389090  1.389090             rut
# 403  1.389817  1.389817             rut

# %%
deltaH_cols = [col for col in merged_df.columns if col.startswith("DeltaH_")]
# merged_df['Min_DeltaH'] = merged_df[deltaH_cols].min(axis=1)
merged_df['Min_Crystal_DeltaH'] = merged_df[deltaH_cols].idxmin(axis=1).str.split('_').str[-1]

# %%
merged_df
# Out:
#                       Formula  sigma bond length_aPbO2  Cation sigma_aPbO2  \
# 628  ['Hf', 'Pb', 'Sn', 'Zr']                 0.065397            0.032896
# 664  ['Hf', 'Sn', 'Ti', 'Zr']                 0.094455            0.029936
# 751  ['Ir', 'Pt', 'Rh', 'Ru']                      NaN                 NaN
# 626  ['Hf', 'Pb', 'Sn', 'Ti']                 0.098810            0.035875
# 613  ['Hf', 'Pb', 'Pt', 'Sn']                      NaN                 NaN
# ..                        ...                      ...                 ...
# 66   ['Ce', 'Hf', 'Ir', 'Nb']                 0.112632            0.084581
# 134  ['Ce', 'Ir', 'Nb', 'Ti']                 0.155463            0.085225
# 132  ['Ce', 'Ir', 'Nb', 'Ru']                      NaN                 NaN
# 32   ['Ce', 'Ge', 'Nb', 'Ru']                 0.149143            0.100796
# 12   ['Ce', 'Ge', 'Ir', 'Nb']                 0.148708            0.100434
#
#      DeltaH_aPbO2  sigma bond length_bad  Cation sigma_bad  DeltaH_bad  \
# 628      0.057140               0.066538          0.036035    0.057542
# 664      0.075097                    NaN               NaN         NaN
# 751           NaN                    NaN               NaN         NaN
# 626      0.101784               0.100108          0.035562    0.103064
# 613           NaN               0.070457          0.049715    0.113711
# ..            ...                    ...               ...         ...
# 66       0.603963               0.131638          0.089863    0.580912
# 134      0.602992               0.158270          0.074933    0.595066
# 132           NaN               0.115502          0.084847    0.634267
# 32       0.622408                    NaN               NaN         NaN
# 12       0.650479                    NaN               NaN         NaN
#
#      sigma bond length_rut  Cation sigma_rut  DeltaH_rut  rho_aPbO2   rho_bad  \
# 628               0.041580          0.033870    0.047034   0.945108  1.008977
# 664               0.066255          0.032920    0.079332   1.000000       NaN
# 751               0.148573          0.039978    0.037992        NaN       NaN
# 626               0.077415          0.033567    0.078150   1.279286  1.283504
# 613               0.060433          0.038467    0.085627        NaN  1.589145
# ..                     ...               ...         ...        ...       ...
# 66                0.104667          0.086277    0.596077   6.027610  5.867256
# 134               0.130600          0.086657    0.605865   6.024057  5.876028
# 132               0.111272          0.076903    0.647576        NaN  6.299539
# 32                0.159165          0.104645    0.641258   6.325723       NaN
# 12                0.151050          0.094013    0.665671   6.568261       NaN
#
#       rho_rut   Min_rho Min_Crystal_rho Min_Crystal_DeltaH
# 628  0.914431  0.914431             rut                rut
# 664  1.078258  1.000000           aPbO2              aPbO2
# 751  1.009792  1.009792             rut                rut
# 626  1.081725  1.081725             rut                rut
# 613  1.214754  1.214754             rut                rut
# ..        ...       ...             ...                ...
# 66   5.971160  5.867256             bad                bad
# 134  6.060900  5.876028             bad                bad
# 132  6.362372  6.299539             bad                bad
# 32   6.524402  6.325723           aPbO2              aPbO2
# 12   6.649680  6.568261           aPbO2              aPbO2
#
# [996 rows x 16 columns]

# %%
cat_cols = [col for col in merged_df.columns if col.startswith("Cation sigma_")]
# merged_df['Min_sigma'] = merged_df[cat_cols].min(axis=1)
merged_df['Min_Crystal_sigma'] = merged_df[cat_cols].idxmin(axis=1).str.split('_').str[-1]
# merged_df = merged_df.sort_values(by='Min_sigma')
merged_df
# Out:
#                       Formula  sigma bond length_aPbO2  Cation sigma_aPbO2  \
# 628  ['Hf', 'Pb', 'Sn', 'Zr']                 0.065397            0.032896
# 664  ['Hf', 'Sn', 'Ti', 'Zr']                 0.094455            0.029936
# 751  ['Ir', 'Pt', 'Rh', 'Ru']                      NaN                 NaN
# 626  ['Hf', 'Pb', 'Sn', 'Ti']                 0.098810            0.035875
# 613  ['Hf', 'Pb', 'Pt', 'Sn']                      NaN                 NaN
# ..                        ...                      ...                 ...
# 66   ['Ce', 'Hf', 'Ir', 'Nb']                 0.112632            0.084581
# 134  ['Ce', 'Ir', 'Nb', 'Ti']                 0.155463            0.085225
# 132  ['Ce', 'Ir', 'Nb', 'Ru']                      NaN                 NaN
# 32   ['Ce', 'Ge', 'Nb', 'Ru']                 0.149143            0.100796
# 12   ['Ce', 'Ge', 'Ir', 'Nb']                 0.148708            0.100434
#
#      DeltaH_aPbO2  sigma bond length_bad  Cation sigma_bad  DeltaH_bad  \
# 628      0.057140               0.066538          0.036035    0.057542
# 664      0.075097                    NaN               NaN         NaN
# 751           NaN                    NaN               NaN         NaN
# 626      0.101784               0.100108          0.035562    0.103064
# 613           NaN               0.070457          0.049715    0.113711
# ..            ...                    ...               ...         ...
# 66       0.603963               0.131638          0.089863    0.580912
# 134      0.602992               0.158270          0.074933    0.595066
# 132           NaN               0.115502          0.084847    0.634267
# 32       0.622408                    NaN               NaN         NaN
# 12       0.650479                    NaN               NaN         NaN
#
#      sigma bond length_rut  Cation sigma_rut  DeltaH_rut  rho_aPbO2   rho_bad  \
# 628               0.041580          0.033870    0.047034   0.945108  1.008977
# 664               0.066255          0.032920    0.079332   1.000000       NaN
# 751               0.148573          0.039978    0.037992        NaN       NaN
# 626               0.077415          0.033567    0.078150   1.279286  1.283504
# 613               0.060433          0.038467    0.085627        NaN  1.589145
# ..                     ...               ...         ...        ...       ...
# 66                0.104667          0.086277    0.596077   6.027610  5.867256
# 134               0.130600          0.086657    0.605865   6.024057  5.876028
# 132               0.111272          0.076903    0.647576        NaN  6.299539
# 32                0.159165          0.104645    0.641258   6.325723       NaN
# 12                0.151050          0.094013    0.665671   6.568261       NaN
#
#       rho_rut   Min_rho Min_Crystal_rho Min_Crystal_DeltaH Min_Crystal_sigma
# 628  0.914431  0.914431             rut                rut             aPbO2
# 664  1.078258  1.000000           aPbO2              aPbO2             aPbO2
# 751  1.009792  1.009792             rut                rut               rut
# 626  1.081725  1.081725             rut                rut               rut
# 613  1.214754  1.214754             rut                rut               rut
# ..        ...       ...             ...                ...               ...
# 66   5.971160  5.867256             bad                bad             aPbO2
# 134  6.060900  5.876028             bad                bad               bad
# 132  6.362372  6.299539             bad                bad               rut
# 32   6.524402  6.325723           aPbO2              aPbO2             aPbO2
# 12   6.649680  6.568261           aPbO2              aPbO2               rut
#
# [996 rows x 17 columns]

# %%
csvfilestr = "./SUMMARY_4comp_alpha_bad_rutile_rho_ordered.csv"
merged_df.to_csv(csvfilestr, index=False)

# %%
exclude_list = ['']
filtered_df = merged_df.copy()

for element in exclude_list:
    filtered_df = filtered_df[~filtered_df['Formula'].str.contains(fr"{element}", na=False)]

filtered_df
